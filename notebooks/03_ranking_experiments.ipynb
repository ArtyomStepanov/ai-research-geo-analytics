# %% [markdown]
# # 03 — Ranking Experiments
#
# Что должно быть в ноутбуке:
# - baseline ranking: ближайшие N объектов
# - ranking по composite score (distance + density + rating)
# - ranking по «underservedness» (обратная плотность)
# - сравнение метрик: precision@k на benchmark-запросах, средняя дистанция, разнообразие
# - выводы и гипотезы для дальнейшей работы

# %%
import sys
sys.path.append('..')

from tools import ranking, search

# %%
# TODO: load benchmark queries from evaluation/benchmark_queries.json
# TODO: run different ranking strategies and compare
