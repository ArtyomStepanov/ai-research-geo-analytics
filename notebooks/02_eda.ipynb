# %% [markdown]
# # 02 — Exploratory Data Analysis
#
# Что должно быть в ноутбуке:
# - распределение объектов по категориям
# - heatmaps плотности
# - доля missing values (name, opening_hours, ...)
# - density analysis по районам / гексам H3
# - гипотезы о районах с дефицитом услуг

# %%
import geopandas as gpd
import pandas as pd
from pathlib import Path

RAW = Path('../data/raw')
# gdf = gpd.read_file(RAW / 'amenities.geojson')

# %%
# TODO: category counts
# gdf['amenity'].value_counts()

# %%
# TODO: heatmap via folium.plugins.HeatMap
